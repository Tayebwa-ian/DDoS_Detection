# %%
import numpy as np
import pandas as pd
import glob, os

# %%
# Define the folder path containing your CSV files
folder_path = "Dataset"

# Find all CSV files in that folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Create a list to hold all DataFrames
dfs = []

# Loop through the files and read them
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)
    
# Merge all CSVs into a single DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Display first few rows to confirm merge
display(merged_df.head())
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0               3268       112740690                  32
# 1                389       112740560                  32
# 2                  0       113757377                 545
# 3               5355          100126                  22
# 4                  0           54760                   4
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       16                         6448
# 1                       16                         6448
# 2                        0                            0
# 3                        0                          616
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          1152                     403
# 1                          5056                     403
# 2                             0                       0
# 3                             0                      28
# 4                             0                       0
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                    201.5              204.724205
# 1                       0                    201.5              204.724205
# 2                       0                      0.0                0.000000
# 3                      28                     28.0                0.000000
# 4                       0                      0.0                0.000000
#
#    ...   min_seg_size_forward   Active Mean    Active Std   Active Max  \
# 0  ...                     32  3.594286e+02  1.199802e+01          380
# 1  ...                     32  3.202857e+02  1.574499e+01          330
# 2  ...                      0  9.361829e+06  7.324646e+06     18900000
# 3  ...                     32  0.000000e+00  0.000000e+00            0
# 4  ...                      0  0.000000e+00  0.000000e+00            0
#
#     Active Min   Idle Mean      Idle Std   Idle Max   Idle Min   Label
# 0          343  16100000.0  4.988048e+05   16400000   15400000  BENIGN
# 1          285  16100000.0  4.987937e+05   16400000   15400000  BENIGN
# 2           19  12200000.0  6.935824e+06   20800000    5504997  BENIGN
# 3            0         0.0  0.000000e+00          0          0  BENIGN
# 4            0         0.0  0.000000e+00          0          0  BENIGN
#
# [5 rows x 79 columns]

# %% [markdown]
# ### Data Inspection

# %%
merged_df.info()
merged_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416778 entries, 0 to 416777
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             416778 non-null  int64
#  1    Flow Duration                416778 non-null  int64
#  2    Total Fwd Packets            416778 non-null  int64
#  3    Total Backward Packets       416778 non-null  int64
#  4   Total Length of Fwd Packets   416778 non-null  int64
#  5    Total Length of Bwd Packets  416778 non-null  int64
#  6    Fwd Packet Length Max        416778 non-null  int64
#  7    Fwd Packet Length Min        416778 non-null  int64
#  8    Fwd Packet Length Mean       416778 non-null  float64
#  9    Fwd Packet Length Std        416778 non-null  float64
#  10  Bwd Packet Length Max         416778 non-null  int64
#  11   Bwd Packet Length Min        416778 non-null  int64
#  12   Bwd Packet Length Mean       416778 non-null  float64
#  13   Bwd Packet Length Std        416778 non-null  float64
#  14  Flow Bytes/s                  416746 non-null  float64
#  15   Flow Packets/s               416778 non-null  float64
#  16   Flow IAT Mean                416778 non-null  float64
#  17   Flow IAT Std                 416778 non-null  float64
#  18   Flow IAT Max                 416778 non-null  int64
#  19   Flow IAT Min                 416778 non-null  int64
#  20  Fwd IAT Total                 416778 non-null  int64
#  21   Fwd IAT Mean                 416778 non-null  float64
#  22   Fwd IAT Std                  416778 non-null  float64
#  23   Fwd IAT Max                  416778 non-null  int64
#  24   Fwd IAT Min                  416778 non-null  int64
#  25  Bwd IAT Total                 416778 non-null  int64
#  26   Bwd IAT Mean                 416778 non-null  float64
#  27   Bwd IAT Std                  416778 non-null  float64
#  28   Bwd IAT Max                  416778 non-null  int64
#  29   Bwd IAT Min                  416778 non-null  int64
#  30  Fwd PSH Flags                 416778 non-null  int64
#  31   Bwd PSH Flags                416778 non-null  int64
#  32   Fwd URG Flags                416778 non-null  int64
#  33   Bwd URG Flags                416778 non-null  int64
#  34   Fwd Header Length            416778 non-null  int64
#  35   Bwd Header Length            416778 non-null  int64
#  36  Fwd Packets/s                 416778 non-null  float64
#  37   Bwd Packets/s                416778 non-null  float64
#  38   Min Packet Length            416778 non-null  int64
#  39   Max Packet Length            416778 non-null  int64
#  40   Packet Length Mean           416778 non-null  float64
#  41   Packet Length Std            416778 non-null  float64
#  42   Packet Length Variance       416778 non-null  float64
#  43  FIN Flag Count                416778 non-null  int64
#  44   SYN Flag Count               416778 non-null  int64
#  45   RST Flag Count               416778 non-null  int64
#  46   PSH Flag Count               416778 non-null  int64
#  47   ACK Flag Count               416778 non-null  int64
#  48   URG Flag Count               416778 non-null  int64
#  49   CWE Flag Count               416778 non-null  int64
#  50   ECE Flag Count               416778 non-null  int64
#  51   Down/Up Ratio                416778 non-null  int64
#  52   Average Packet Size          416778 non-null  float64
#  53   Avg Fwd Segment Size         416778 non-null  float64
#  54   Avg Bwd Segment Size         416778 non-null  float64
#  55   Fwd Header Length.1          416778 non-null  int64
#  56  Fwd Avg Bytes/Bulk            416778 non-null  int64
#  57   Fwd Avg Packets/Bulk         416778 non-null  int64
#  58   Fwd Avg Bulk Rate            416778 non-null  int64
#  59   Bwd Avg Bytes/Bulk           416778 non-null  int64
#  60   Bwd Avg Packets/Bulk         416778 non-null  int64
#  61  Bwd Avg Bulk Rate             416778 non-null  int64
#  62  Subflow Fwd Packets           416778 non-null  int64
#  63   Subflow Fwd Bytes            416778 non-null  int64
#  64   Subflow Bwd Packets          416778 non-null  int64
#  65   Subflow Bwd Bytes            416778 non-null  int64
#  66  Init_Win_bytes_forward        416778 non-null  int64
#  67   Init_Win_bytes_backward      416778 non-null  int64
#  68   act_data_pkt_fwd             416778 non-null  int64
#  69   min_seg_size_forward         416778 non-null  int64
#  70  Active Mean                   416778 non-null  float64
#  71   Active Std                   416778 non-null  float64
#  72   Active Max                   416778 non-null  int64
#  73   Active Min                   416778 non-null  int64
#  74  Idle Mean                     416778 non-null  float64
#  75   Idle Std                     416778 non-null  float64
#  76   Idle Max                     416778 non-null  int64
#  77   Idle Min                     416778 non-null  int64
#  78   Label                        416778 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 251.2+ MB
# /home/passwd/DDoS_Detection/venv/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/passwd/DDoS_Detection/venv/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#          Destination Port   Flow Duration   Total Fwd Packets  \
# count       416778.000000    4.167780e+05       416778.000000
# unique                NaN             NaN                 NaN
# top                   NaN             NaN                 NaN
# freq                  NaN             NaN                 NaN
# mean          7906.276274    1.413474e+07            8.977957
# std          18446.810820    3.123366e+07          743.301976
# min              0.000000   -1.200000e+01            1.000000
# 25%             53.000000    7.729000e+03            2.000000
# 50%             80.000000    1.964465e+05            3.000000
# 75%            443.000000    6.010748e+06            5.000000
# max          65532.000000    1.200000e+08       207964.000000
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# count             416778.000000                 4.167780e+05
# unique                      NaN                          NaN
# top                         NaN                          NaN
# freq                        NaN                          NaN
# mean                  10.000149                 7.838437e+02
# std                 1001.993632                 5.876146e+03
# min                    0.000000                 0.000000e+00
# 25%                    1.000000                 2.600000e+01
# 50%                    2.000000                 5.200000e+01
# 75%                    5.000000                 9.200000e+01
# max               284602.000000                 1.235152e+06
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# count                   4.167780e+05           416778.000000
# unique                           NaN                     NaN
# top                              NaN                     NaN
# freq                             NaN                     NaN
# mean                    1.623920e+04              371.776399
# std                     2.244220e+06             1433.866753
# min                     0.000000e+00                0.000000
# 25%                     6.000000e+00                6.000000
# 50%                     1.560000e+02               30.000000
# 75%                     4.799000e+03               49.000000
# max                     6.270000e+08            24820.000000
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
# count            416778.000000            416778.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                 26.055864               113.055645
# std                 123.520052               384.081840
# min                   0.000000                 0.000000
# 25%                   0.000000                 6.000000
# 50%                   6.000000                18.500000
# 75%                  33.000000                46.000000
# max                2325.000000              5940.857143
#
#          Fwd Packet Length Std  ...   min_seg_size_forward   Active Mean  \
# count            416778.000000  ...          416778.000000  4.167780e+05
# unique                     NaN  ...                    NaN           NaN
# top                        NaN  ...                    NaN           NaN
# freq                       NaN  ...                    NaN           NaN
# mean                139.409830  ...              23.363232  1.395114e+05
# std                 602.451016  ...               5.678366  8.322997e+05
# min                   0.000000  ...               0.000000  0.000000e+00
# 25%                   0.000000  ...              20.000000  0.000000e+00
# 50%                   0.000000  ...              20.000000  0.000000e+00
# 75%                  10.263203  ...              32.000000  6.950000e+02
# max                7049.469004  ...              56.000000  1.060000e+08
#
#           Active Std    Active Max    Active Min     Idle Mean      Idle Std  \
# count   4.167780e+05  4.167780e+05  4.167780e+05  4.167780e+05  4.167780e+05
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    3.167875e+04  1.968158e+05  1.218275e+05  7.386322e+06  2.036628e+06
# std     3.684340e+05  1.120016e+06  7.768930e+05  1.889940e+07  9.655660e+06
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%     0.000000e+00  6.950000e+02  6.660000e+02  5.588871e+06  0.000000e+00
# max     5.040000e+07  1.060000e+08  1.060000e+08  1.200000e+08  7.660000e+07
#
#             Idle Max      Idle Min   Label
# count   4.167780e+05  4.167780e+05  416778
# unique           NaN           NaN       3
# top              NaN           NaN  BENIGN
# freq             NaN           NaN  286785
# mean    8.830855e+06  5.917528e+06     NaN
# std     2.246942e+07  1.740956e+07     NaN
# min     0.000000e+00  0.000000e+00     NaN
# 25%     0.000000e+00  0.000000e+00     NaN
# 50%     0.000000e+00  0.000000e+00     NaN
# 75%     5.588911e+06  5.346825e+06     NaN
# max     1.200000e+08  1.200000e+08     NaN
#
# [11 rows x 79 columns]

# %%
# labels in data
print(merged_df[' Label'].unique())
# Out:
# ['BENIGN' 'Bot' 'DDoS']

# %% [markdown]
# ### Check for null and Infinity values in Columns and drop rows with null values

# %%
# find out which many null values exist per feature/column
for col in merged_df.columns:
    has_null = merged_df[col].isnull().any()   # Returns True if column has at least one null
    if has_null:
        print(f"{col}: {has_null}")
# Out:
# Flow Bytes/s: True

# %%
# drop rows with null values
merged_df.dropna(inplace=True)

# %% [markdown]
# #### Remove rows with infinity values

# %%
# Make a copy to avoid modifying the original DataFrame accidentally
df = merged_df.copy()

# Identify numeric columns only (skip non-numerical ones like label)
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Check for infinite values (only in numeric columns)
inf_counts = np.isinf(df[numeric_cols]).sum()

# Display only columns that contain infinity
inf_columns = inf_counts[inf_counts > 0]

if not inf_columns.empty:
    print("Columns containing infinity values:")
    for col, count in inf_columns.items():
        print(f" - {col}: {count} infinite values")
else:
    print("No infinite values found in numeric columns.")

# Drop rows that contain any infinity values (across all numeric columns)
rows_before = len(df)
df = df[~np.isinf(df[numeric_cols]).any(axis=1)].copy()
rows_after = len(df)

print(f"Rows with infinity values removed: {rows_before - rows_after}")
print(f"Remaining rows: {rows_after}")

# Replace the original DataFrame if desired
merged_df = df
# Out:
# No infinite values found in numeric columns.
# Rows with infinity values removed: 0
# Remaining rows: 416622

# %% [markdown]
# ### Check and remove duplicates

# %%
merged_df.duplicated().sum()
merged_df.drop_duplicates(inplace=True)
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 405401 entries, 0 to 416777
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             405401 non-null  int64
#  1    Flow Duration                405401 non-null  int64
#  2    Total Fwd Packets            405401 non-null  int64
#  3    Total Backward Packets       405401 non-null  int64
#  4   Total Length of Fwd Packets   405401 non-null  int64
#  5    Total Length of Bwd Packets  405401 non-null  int64
#  6    Fwd Packet Length Max        405401 non-null  int64
#  7    Fwd Packet Length Min        405401 non-null  int64
#  8    Fwd Packet Length Mean       405401 non-null  float64
#  9    Fwd Packet Length Std        405401 non-null  float64
#  10  Bwd Packet Length Max         405401 non-null  int64
#  11   Bwd Packet Length Min        405401 non-null  int64
#  12   Bwd Packet Length Mean       405401 non-null  float64
#  13   Bwd Packet Length Std        405401 non-null  float64
#  14  Flow Bytes/s                  405401 non-null  float64
#  15   Flow Packets/s               405401 non-null  float64
#  16   Flow IAT Mean                405401 non-null  float64
#  17   Flow IAT Std                 405401 non-null  float64
#  18   Flow IAT Max                 405401 non-null  int64
#  19   Flow IAT Min                 405401 non-null  int64
#  20  Fwd IAT Total                 405401 non-null  int64
#  21   Fwd IAT Mean                 405401 non-null  float64
#  22   Fwd IAT Std                  405401 non-null  float64
#  23   Fwd IAT Max                  405401 non-null  int64
#  24   Fwd IAT Min                  405401 non-null  int64
#  25  Bwd IAT Total                 405401 non-null  int64
#  26   Bwd IAT Mean                 405401 non-null  float64
#  27   Bwd IAT Std                  405401 non-null  float64
#  28   Bwd IAT Max                  405401 non-null  int64
#  29   Bwd IAT Min                  405401 non-null  int64
#  30  Fwd PSH Flags                 405401 non-null  int64
#  31   Bwd PSH Flags                405401 non-null  int64
#  32   Fwd URG Flags                405401 non-null  int64
#  33   Bwd URG Flags                405401 non-null  int64
#  34   Fwd Header Length            405401 non-null  int64
#  35   Bwd Header Length            405401 non-null  int64
#  36  Fwd Packets/s                 405401 non-null  float64
#  37   Bwd Packets/s                405401 non-null  float64
#  38   Min Packet Length            405401 non-null  int64
#  39   Max Packet Length            405401 non-null  int64
#  40   Packet Length Mean           405401 non-null  float64
#  41   Packet Length Std            405401 non-null  float64
#  42   Packet Length Variance       405401 non-null  float64
#  43  FIN Flag Count                405401 non-null  int64
#  44   SYN Flag Count               405401 non-null  int64
#  45   RST Flag Count               405401 non-null  int64
#  46   PSH Flag Count               405401 non-null  int64
#  47   ACK Flag Count               405401 non-null  int64
#  48   URG Flag Count               405401 non-null  int64
#  49   CWE Flag Count               405401 non-null  int64
#  50   ECE Flag Count               405401 non-null  int64
#  51   Down/Up Ratio                405401 non-null  int64
#  52   Average Packet Size          405401 non-null  float64
#  53   Avg Fwd Segment Size         405401 non-null  float64
#  54   Avg Bwd Segment Size         405401 non-null  float64
#  55   Fwd Header Length.1          405401 non-null  int64
#  56  Fwd Avg Bytes/Bulk            405401 non-null  int64
#  57   Fwd Avg Packets/Bulk         405401 non-null  int64
#  58   Fwd Avg Bulk Rate            405401 non-null  int64
#  59   Bwd Avg Bytes/Bulk           405401 non-null  int64
#  60   Bwd Avg Packets/Bulk         405401 non-null  int64
#  61  Bwd Avg Bulk Rate             405401 non-null  int64
#  62  Subflow Fwd Packets           405401 non-null  int64
#  63   Subflow Fwd Bytes            405401 non-null  int64
#  64   Subflow Bwd Packets          405401 non-null  int64
#  65   Subflow Bwd Bytes            405401 non-null  int64
#  66  Init_Win_bytes_forward        405401 non-null  int64
#  67   Init_Win_bytes_backward      405401 non-null  int64
#  68   act_data_pkt_fwd             405401 non-null  int64
#  69   min_seg_size_forward         405401 non-null  int64
#  70  Active Mean                   405401 non-null  float64
#  71   Active Std                   405401 non-null  float64
#  72   Active Max                   405401 non-null  int64
#  73   Active Min                   405401 non-null  int64
#  74  Idle Mean                     405401 non-null  float64
#  75   Idle Std                     405401 non-null  float64
#  76   Idle Max                     405401 non-null  int64
#  77   Idle Min                     405401 non-null  int64
#  78   Label                        405401 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 247.4+ MB

# %% [markdown]
# ### Save the cleaned data

# %%
merged_df.to_csv("clean_data/cleaned_DDoS_and_begnin_traffic_dataset.csv", index=False)
